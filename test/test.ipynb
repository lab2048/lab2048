# %% [markdown]
# # Using VISTool

# %%
from lab2048 import VISTool as vis
from collections import Counter
import random 
alist = [random.randint(1, 10) for _ in range(1000)]
vis.plot_counter(Counter(alist))

# %% [markdown]
# # Using TMTool

# %%
from lab2048 import TMTool
tm = TMTool.TMTool()
display(tm.userdict)
display(tm.stopwords)
# Out:
# ['陳水扁',
#  '年輕人',
#  '台灣人',
#  '大陸人',
#  '中國人',
#  '青年',
#  '新鮮人',
#  '年輕人',
#  '三四年級生',
#  '四年級生',
#  '五年級生',
#  '四、五年級生',
#  '七八年級',
#  '七八年級生',
#  '七、八年級',
#  '7年級生',
#  '8年級生',
#  '七年級',
#  '八年級',
#  '七年級生',
#  '八年級生',
#  '90後',
#  '80後',
#  '月光族',
#  '麻糬族',
#  '草莓族',
#  '青貧族',
#  '窮忙族',
#  '嗑藥一族',
#  '靠爸族',
#  '靠媽族',
#  '首購族',
#  '首投族',
#  '躺平族',
#  '這一代',
#  '學運世代',
#  'X世代',
#  'Y世代',
#  'Z世代',
#  '鮭魚世代',
#  '反啟蒙世代',
#  '三明治世代',
#  '崩世代',
#  '丫世代',
#  'Y世代',
#  '新世代',
#  'Ｘ世代',
#  '富二代',
#  '草莓世代',
#  '千禧世代',
#  '年輕男女',
#  '新鮮人',
#  '菜鳥兵',
#  '新兵',
#  '鑰匙兒童',
#  '新人類',
#  '新新人類',
#  '青少年',
#  '大學生',
#  '單身寄生蟲',
#  '爛草莓',
#  '宅男',
#  '宅女',
#  '小皇帝',
#  '小公主',
#  '公主病',
#  '搖頭丸',
#  '民進黨',
#  '臺灣人',
#  '馬英九',
#  '哈利波特',
#  '青年黨',
#  '樁腳',
#  '性行為',
#  '蔡英文',
#  '台灣',
#  '台湾',
#  '老共',
#  '習大大',
#  '民進黨',
#  '中天',
#  '舔共',
#  '反送中',
#  '送中',
#  '逃犯條例',
#  '韩国瑜',
#  '韩市長',
#  '中國人',
#  '台灣人',
#  '臺灣人',
#  '台湾人',
#  '大陆人',
#  '中国人',
#  '柯文哲']
# [',',
#  '?',
#  '、',
#  '。',
# ...
